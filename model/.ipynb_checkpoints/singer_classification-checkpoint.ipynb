# %% [markdown]
# <h2 style='color:blue' align='center'>Singer Celebrities Classification (SVM)<h2>

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h3 style='color:purple'>(1) Preprocessing: Detect face and eyes</h3>

# %%
img = cv2.imread('./test_image/ryan_tedder1.jpg')
img.shape
# Out:
# (1334, 2000, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1334, 2000)

# %%
gray
# Out:
# array([[251, 251, 251, ..., 188, 188, 188],
#        [251, 251, 251, ..., 188, 188, 188],
#        [251, 251, 251, ..., 188, 188, 188],
#        ...,
#        [172, 172, 172, ..., 159, 159, 158],
#        [172, 172, 172, ..., 159, 159, 158],
#        [172, 172, 172, ..., 160, 159, 159]], dtype=uint8)

# %%
plt.imshow(gray, cmap = "gray")

# %% [markdown]
# ###  HaarsCascade

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5) #??
faces # return an array of 4-values (x,y,w,h) (position of the face)
# Out:
# array([[746, 249, 468, 468]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (746, 249, 468, 468)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),5)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),5)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
cropped_image = get_cropped_image_if_2_eyes("./test_image/ryan_tedder1.jpg")
plt.imshow(cropped_image)

# %%
org_image_obstructed = cv2.imread("./test_image/ryan_tedder2.jpg")
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes("./test_image/ryan_tedder2.jpg")
cropped_image_no_2_eyes

# %%
path_to_data = "./image_dataset/"
path_to_cropped_data = "./image_dataset/cropped"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)
img_dirs
# Out:
# ['./image_dataset/adam_levine',
#  './image_dataset/cropped',
#  './image_dataset/katy_perry',
#  './image_dataset/rihanna',
#  './image_dataset/ryan_tedder']

# %%
import shutil
if os.path.exists(path_to_cropped_data):
     shutil.rmtree(path_to_cropped_data)
os.mkdir(path_to_cropped_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        try:
            roi_color = get_cropped_image_if_2_eyes(entry.path)
        except:
            continue
        if roi_color is not None:
            cropped_folder_path = path_to_cropped_data + celebrity_name
            if not os.path.exists(cropped_folder_path):
                os.makedirs(cropped_folder_path)
                cropped_image_dirs.append(cropped_folder_path)
                print("Generating cropped images in folder: ",cropped_folder_path)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder_path + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./image_dataset/cropped/adam_levine
# Generating cropped images in folder:  ./image_dataset/cropped/katy_perry
# Generating cropped images in folder:  ./image_dataset/cropped/rihanna
# Generating cropped images in folder:  ./image_dataset/cropped/ryan_tedder

# %% [markdown]
# ### Wavelet transform

# %%
#import from stackoverflow
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_image,'db1',5)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# ### Transfrorm & create X-Y training set

# %%
#1. Transform the image 
#2. Stack theoriginal &the transformed img vertically (celebrity_file_names_dict)
celebrity_file_names_dict
# Out:
# {'adam_levine': ['./image_dataset/cropped/adam_levine/adam_levine1.png',
#   './image_dataset/cropped/adam_levine/adam_levine2.png',
#   './image_dataset/cropped/adam_levine/adam_levine3.png',
#   './image_dataset/cropped/adam_levine/adam_levine4.png',
#   './image_dataset/cropped/adam_levine/adam_levine5.png',
#   './image_dataset/cropped/adam_levine/adam_levine6.png',
#   './image_dataset/cropped/adam_levine/adam_levine7.png',
#   './image_dataset/cropped/adam_levine/adam_levine8.png',
#   './image_dataset/cropped/adam_levine/adam_levine9.png',
#   './image_dataset/cropped/adam_levine/adam_levine10.png',
#   './image_dataset/cropped/adam_levine/adam_levine11.png',
#   './image_dataset/cropped/adam_levine/adam_levine12.png',
#   './image_dataset/cropped/adam_levine/adam_levine13.png',
#   './image_dataset/cropped/adam_levine/adam_levine14.png',
#   './image_dataset/cropped/adam_levine/adam_levine15.png',
#   './image_dataset/cropped/adam_levine/adam_levine16.png',
#   './image_dataset/cropped/adam_levine/adam_levine17.png',
#   './image_dataset/cropped/adam_levine/adam_levine18.png',
#   './image_dataset/cropped/adam_levine/adam_levine19.png',
#   './image_dataset/cropped/adam_levine/adam_levine20.png',
#   './image_dataset/cropped/adam_levine/adam_levine21.png',
#   './image_dataset/cropped/adam_levine/adam_levine22.png',
#   './image_dataset/cropped/adam_levine/adam_levine23.png',
#   './image_dataset/cropped/adam_levine/adam_levine24.png',
#   './image_dataset/cropped/adam_levine/adam_levine25.png',
#   './image_dataset/cropped/adam_levine/adam_levine26.png',
#   './image_dataset/cropped/adam_levine/adam_levine27.png',
#   './image_dataset/cropped/adam_levine/adam_levine28.png',
#   './image_dataset/cropped/adam_levine/adam_levine29.png',
#   './image_dataset/cropped/adam_levine/adam_levine30.png',
#   './image_dataset/cropped/adam_levine/adam_levine31.png',
#   './image_dataset/cropped/adam_levine/adam_levine32.png'],
#  'cropped': [],
#  'katy_perry': ['./image_dataset/cropped/katy_perry/katy_perry1.png',
#   './image_dataset/cropped/katy_perry/katy_perry2.png',
#   './image_dataset/cropped/katy_perry/katy_perry3.png',
#   './image_dataset/cropped/katy_perry/katy_perry4.png',
#   './image_dataset/cropped/katy_perry/katy_perry5.png',
#   './image_dataset/cropped/katy_perry/katy_perry6.png',
#   './image_dataset/cropped/katy_perry/katy_perry7.png',
#   './image_dataset/cropped/katy_perry/katy_perry8.png',
#   './image_dataset/cropped/katy_perry/katy_perry9.png',
#   './image_dataset/cropped/katy_perry/katy_perry10.png',
#   './image_dataset/cropped/katy_perry/katy_perry11.png',
#   './image_dataset/cropped/katy_perry/katy_perry12.png',
#   './image_dataset/cropped/katy_perry/katy_perry13.png',
#   './image_dataset/cropped/katy_perry/katy_perry14.png',
#   './image_dataset/cropped/katy_perry/katy_perry15.png',
#   './image_dataset/cropped/katy_perry/katy_perry16.png',
#   './image_dataset/cropped/katy_perry/katy_perry17.png',
#   './image_dataset/cropped/katy_perry/katy_perry18.png',
#   './image_dataset/cropped/katy_perry/katy_perry19.png',
#   './image_dataset/cropped/katy_perry/katy_perry20.png',
#   './image_dataset/cropped/katy_perry/katy_perry21.png',
#   './image_dataset/cropped/katy_perry/katy_perry22.png',
#   './image_dataset/cropped/katy_perry/katy_perry23.png',
#   './image_dataset/cropped/katy_perry/katy_perry24.png',
#   './image_dataset/cropped/katy_perry/katy_perry25.png',
#   './image_dataset/cropped/katy_perry/katy_perry26.png',
#   './image_dataset/cropped/katy_perry/katy_perry27.png',
#   './image_dataset/cropped/katy_perry/katy_perry28.png',
#   './image_dataset/cropped/katy_perry/katy_perry29.png',
#   './image_dataset/cropped/katy_perry/katy_perry30.png',
#   './image_dataset/cropped/katy_perry/katy_perry31.png',
#   './image_dataset/cropped/katy_perry/katy_perry32.png',
#   './image_dataset/cropped/katy_perry/katy_perry33.png',
#   './image_dataset/cropped/katy_perry/katy_perry34.png',
#   './image_dataset/cropped/katy_perry/katy_perry35.png',
#   './image_dataset/cropped/katy_perry/katy_perry36.png',
#   './image_dataset/cropped/katy_perry/katy_perry37.png',
#   './image_dataset/cropped/katy_perry/katy_perry38.png',
#   './image_dataset/cropped/katy_perry/katy_perry39.png',
#   './image_dataset/cropped/katy_perry/katy_perry40.png'],
#  'rihanna': ['./image_dataset/cropped/rihanna/rihanna1.png',
#   './image_dataset/cropped/rihanna/rihanna2.png',
#   './image_dataset/cropped/rihanna/rihanna3.png',
#   './image_dataset/cropped/rihanna/rihanna4.png',
#   './image_dataset/cropped/rihanna/rihanna5.png',
#   './image_dataset/cropped/rihanna/rihanna6.png',
#   './image_dataset/cropped/rihanna/rihanna7.png',
#   './image_dataset/cropped/rihanna/rihanna8.png',
#   './image_dataset/cropped/rihanna/rihanna9.png',
#   './image_dataset/cropped/rihanna/rihanna10.png',
#   './image_dataset/cropped/rihanna/rihanna11.png',
#   './image_dataset/cropped/rihanna/rihanna12.png',
#   './image_dataset/cropped/rihanna/rihanna13.png',
#   './image_dataset/cropped/rihanna/rihanna14.png',
#   './image_dataset/cropped/rihanna/rihanna15.png',
#   './image_dataset/cropped/rihanna/rihanna16.png',
#   './image_dataset/cropped/rihanna/rihanna17.png',
#   './image_dataset/cropped/rihanna/rihanna18.png',
#   './image_dataset/cropped/rihanna/rihanna19.png',
#   './image_dataset/cropped/rihanna/rihanna20.png',
#   './image_dataset/cropped/rihanna/rihanna21.png',
#   './image_dataset/cropped/rihanna/rihanna22.png',
#   './image_dataset/cropped/rihanna/rihanna23.png',
#   './image_dataset/cropped/rihanna/rihanna24.png',
#   './image_dataset/cropped/rihanna/rihanna25.png',
#   './image_dataset/cropped/rihanna/rihanna26.png',
#   './image_dataset/cropped/rihanna/rihanna27.png',
#   './image_dataset/cropped/rihanna/rihanna28.png',
#   './image_dataset/cropped/rihanna/rihanna29.png',
#   './image_dataset/cropped/rihanna/rihanna30.png',
#   './image_dataset/cropped/rihanna/rihanna31.png',
#   './image_dataset/cropped/rihanna/rihanna32.png',
#   './image_dataset/cropped/rihanna/rihanna33.png',
#   './image_dataset/cropped/rihanna/rihanna34.png',
#   './image_dataset/cropped/rihanna/rihanna35.png',
#   './image_dataset/cropped/rihanna/rihanna36.png',
#   './image_dataset/cropped/rihanna/rihanna37.png',
#   './image_dataset/cropped/rihanna/rihanna38.png',
#   './image_dataset/cropped/rihanna/rihanna39.png',
#   './image_dataset/cropped/rihanna/rihanna40.png',
#   './image_dataset/cropped/rihanna/rihanna41.png',
#   './image_dataset/cropped/rihanna/rihanna42.png',
#   './image_dataset/cropped/rihanna/rihanna43.png',
#   './image_dataset/cropped/rihanna/rihanna44.png',
#   './image_dataset/cropped/rihanna/rihanna45.png',
#   './image_dataset/cropped/rihanna/rihanna46.png',
#   './image_dataset/cropped/rihanna/rihanna47.png',
#   './image_dataset/cropped/rihanna/rihanna48.png'],
#  'ryan_tedder': ['./image_dataset/cropped/ryan_tedder/ryan_tedder1.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder2.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder3.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder4.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder5.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder6.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder7.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder8.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder9.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder10.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder11.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder12.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder13.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder14.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder15.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder16.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder17.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder18.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder19.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder20.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder21.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder22.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder23.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder24.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder25.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder26.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder27.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder28.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder29.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder30.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder31.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder32.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder33.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder34.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder35.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder36.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder37.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder38.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder39.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder40.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder41.png',
#   './image_dataset/cropped/ryan_tedder/ryan_tedder42.png']}

# %%
cropped_image.shape
# Out:
# (468, 468, 3)

# %%
#after deleting unwanted cropped_img, re-create the celeb dict
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'adam_levine': ['./image_dataset/cropped/adam_levine\\adam_levine1.png',
#   './image_dataset/cropped/adam_levine\\adam_levine10.png',
#   './image_dataset/cropped/adam_levine\\adam_levine11.png',
#   './image_dataset/cropped/adam_levine\\adam_levine12.png',
#   './image_dataset/cropped/adam_levine\\adam_levine14.png',
#   './image_dataset/cropped/adam_levine\\adam_levine15.png',
#   './image_dataset/cropped/adam_levine\\adam_levine16.png',
#   './image_dataset/cropped/adam_levine\\adam_levine17.png',
#   './image_dataset/cropped/adam_levine\\adam_levine18.png',
#   './image_dataset/cropped/adam_levine\\adam_levine19.png',
#   './image_dataset/cropped/adam_levine\\adam_levine2.png',
#   './image_dataset/cropped/adam_levine\\adam_levine20.png',
#   './image_dataset/cropped/adam_levine\\adam_levine21.png',
#   './image_dataset/cropped/adam_levine\\adam_levine22.png',
#   './image_dataset/cropped/adam_levine\\adam_levine23.png',
#   './image_dataset/cropped/adam_levine\\adam_levine24.png',
#   './image_dataset/cropped/adam_levine\\adam_levine26.png',
#   './image_dataset/cropped/adam_levine\\adam_levine28.png',
#   './image_dataset/cropped/adam_levine\\adam_levine29.png',
#   './image_dataset/cropped/adam_levine\\adam_levine3.png',
#   './image_dataset/cropped/adam_levine\\adam_levine30.png',
#   './image_dataset/cropped/adam_levine\\adam_levine31.png',
#   './image_dataset/cropped/adam_levine\\adam_levine32.png',
#   './image_dataset/cropped/adam_levine\\adam_levine4.png',
#   './image_dataset/cropped/adam_levine\\adam_levine5.png',
#   './image_dataset/cropped/adam_levine\\adam_levine6.png',
#   './image_dataset/cropped/adam_levine\\adam_levine7.png'],
#  'katy_perry': ['./image_dataset/cropped/katy_perry\\katy_perry1.png',
#   './image_dataset/cropped/katy_perry\\katy_perry10.png',
#   './image_dataset/cropped/katy_perry\\katy_perry11.png',
#   './image_dataset/cropped/katy_perry\\katy_perry12.png',
#   './image_dataset/cropped/katy_perry\\katy_perry13.png',
#   './image_dataset/cropped/katy_perry\\katy_perry14.png',
#   './image_dataset/cropped/katy_perry\\katy_perry15.png',
#   './image_dataset/cropped/katy_perry\\katy_perry16.png',
#   './image_dataset/cropped/katy_perry\\katy_perry17.png',
#   './image_dataset/cropped/katy_perry\\katy_perry18.png',
#   './image_dataset/cropped/katy_perry\\katy_perry19.png',
#   './image_dataset/cropped/katy_perry\\katy_perry2.png',
#   './image_dataset/cropped/katy_perry\\katy_perry20.png',
#   './image_dataset/cropped/katy_perry\\katy_perry21.png',
#   './image_dataset/cropped/katy_perry\\katy_perry22.png',
#   './image_dataset/cropped/katy_perry\\katy_perry25.png',
#   './image_dataset/cropped/katy_perry\\katy_perry26.png',
#   './image_dataset/cropped/katy_perry\\katy_perry27.png',
#   './image_dataset/cropped/katy_perry\\katy_perry29.png',
#   './image_dataset/cropped/katy_perry\\katy_perry3.png',
#   './image_dataset/cropped/katy_perry\\katy_perry30.png',
#   './image_dataset/cropped/katy_perry\\katy_perry31.png',
#   './image_dataset/cropped/katy_perry\\katy_perry32.png',
#   './image_dataset/cropped/katy_perry\\katy_perry33.png',
#   './image_dataset/cropped/katy_perry\\katy_perry34.png',
#   './image_dataset/cropped/katy_perry\\katy_perry35.png',
#   './image_dataset/cropped/katy_perry\\katy_perry36.png',
#   './image_dataset/cropped/katy_perry\\katy_perry37.png',
#   './image_dataset/cropped/katy_perry\\katy_perry38.png',
#   './image_dataset/cropped/katy_perry\\katy_perry39.png',
#   './image_dataset/cropped/katy_perry\\katy_perry4.png',
#   './image_dataset/cropped/katy_perry\\katy_perry40.png',
#   './image_dataset/cropped/katy_perry\\katy_perry5.png',
#   './image_dataset/cropped/katy_perry\\katy_perry6.png',
#   './image_dataset/cropped/katy_perry\\katy_perry9.png'],
#  'rihanna': ['./image_dataset/cropped/rihanna\\rihanna1.png',
#   './image_dataset/cropped/rihanna\\rihanna10.png',
#   './image_dataset/cropped/rihanna\\rihanna12.png',
#   './image_dataset/cropped/rihanna\\rihanna13.png',
#   './image_dataset/cropped/rihanna\\rihanna15.png',
#   './image_dataset/cropped/rihanna\\rihanna16.png',
#   './image_dataset/cropped/rihanna\\rihanna18.png',
#   './image_dataset/cropped/rihanna\\rihanna19.png',
#   './image_dataset/cropped/rihanna\\rihanna2.png',
#   './image_dataset/cropped/rihanna\\rihanna20.png',
#   './image_dataset/cropped/rihanna\\rihanna21.png',
#   './image_dataset/cropped/rihanna\\rihanna22.png',
#   './image_dataset/cropped/rihanna\\rihanna23.png',
#   './image_dataset/cropped/rihanna\\rihanna24.png',
#   './image_dataset/cropped/rihanna\\rihanna25.png',
#   './image_dataset/cropped/rihanna\\rihanna26.png',
#   './image_dataset/cropped/rihanna\\rihanna27.png',
#   './image_dataset/cropped/rihanna\\rihanna29.png',
#   './image_dataset/cropped/rihanna\\rihanna3.png',
#   './image_dataset/cropped/rihanna\\rihanna31.png',
#   './image_dataset/cropped/rihanna\\rihanna34.png',
#   './image_dataset/cropped/rihanna\\rihanna36.png',
#   './image_dataset/cropped/rihanna\\rihanna37.png',
#   './image_dataset/cropped/rihanna\\rihanna38.png',
#   './image_dataset/cropped/rihanna\\rihanna4.png',
#   './image_dataset/cropped/rihanna\\rihanna40.png',
#   './image_dataset/cropped/rihanna\\rihanna41.png',
#   './image_dataset/cropped/rihanna\\rihanna42.png',
#   './image_dataset/cropped/rihanna\\rihanna43.png',
#   './image_dataset/cropped/rihanna\\rihanna44.png',
#   './image_dataset/cropped/rihanna\\rihanna47.png',
#   './image_dataset/cropped/rihanna\\rihanna48.png',
#   './image_dataset/cropped/rihanna\\rihanna5.png',
#   './image_dataset/cropped/rihanna\\rihanna6.png',
#   './image_dataset/cropped/rihanna\\rihanna7.png',
#   './image_dataset/cropped/rihanna\\rihanna8.png',
#   './image_dataset/cropped/rihanna\\rihanna9.png'],
#  'ryan_tedder': ['./image_dataset/cropped/ryan_tedder\\ryan_tedder1.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder10.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder11.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder12.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder13.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder14.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder16.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder17.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder18.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder19.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder2.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder21.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder22.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder23.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder24.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder26.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder27.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder29.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder3.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder30.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder31.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder32.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder33.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder34.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder35.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder36.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder37.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder38.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder4.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder40.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder42.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder5.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder6.png',
#   './image_dataset/cropped/ryan_tedder\\ryan_tedder7.png']}

# %%
#because y cannot be a name => tranform name to number
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'adam_levine': 0, 'katy_perry': 1, 'rihanna': 2, 'ryan_tedder': 3}

# %%
X, y = [], [] # y has to be some number (1, 2, 3, 4)
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scaled_raw_img = cv2.resize(img, (32, 32)) #need to have same size between X & Y (X => Y mapping)
        img_har = w2d(img,'db1',5)
        scaled_img_har = cv2.resize(img_har, (32, 32)) #need to have same size between X & Y (X => Y mapping)
        combined_img = np.vstack((scaled_raw_img.reshape(32*32*3,1),scaled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X) # no of img in 4 folders
# Out:
# 133

# %%
len(X[0]) # = 32*32*3 + 32*32*1
# Out:
# 4096

# %%
X[0]# an array of pixel values (integer)(2D array)
# Out:
# array([[ 47],
#        [ 53],
#        [ 72],
#        ...,
#        [253],
#        [199],
#        [251]], dtype=uint8)

# %%
type(X), X
# Out:
# (list,
#  [array([[ 47],
#          [ 53],
#          [ 72],
#          ...,
#          [253],
#          [199],
#          [251]], dtype=uint8),
#   array([[251],
#          [249],
#          [248],
#          ...,
#          [123],
#          [123],
#          [182]], dtype=uint8),
#   array([[ 24],
#          [ 18],
#          [ 34],
#          ...,
#          [244],
#          [243],
#          [241]], dtype=uint8),
#   array([[ 44],
#          [ 46],
#          [ 27],
#          ...,
#          [196],
#          [243],
#          [218]], dtype=uint8),
#   array([[ 4],
#          [ 5],
#          [ 4],
#          ...,
#          [84],
#          [14],
#          [ 4]], dtype=uint8),
#   array([[218],
#          [205],
#          [190],
#          ...,
#          [ 43],
#          [  1],
#          [ 15]], dtype=uint8),
#   array([[ 32],
#          [ 40],
#          [ 40],
#          ...,
#          [252],
#          [251],
#          [252]], dtype=uint8),
#   array([[41],
#          [43],
#          [37],
#          ...,
#          [ 9],
#          [ 4],
#          [ 0]], dtype=uint8),
#   array([[ 21],
#          [ 23],
#          [ 28],
#          ...,
#          [  8],
#          [ 61],
#          [235]], dtype=uint8),
#   array([[  4],
#          [  5],
#          [  9],
#          ...,
#          [240],
#          [241],
#          [241]], dtype=uint8),
#   array([[ 29],
#          [ 42],
#          [ 58],
#          ...,
#          [  3],
#          [  3],
#          [207]], dtype=uint8),
#   array([[236],
#          [209],
#          [174],
#          ...,
#          [140],
#          [255],
#          [  0]], dtype=uint8),
#   array([[232],
#          [232],
#          [250],
#          ...,
#          [ 13],
#          [132],
#          [135]], dtype=uint8),
#   array([[255],
#          [255],
#          [255],
#          ...,
#          [  2],
#          [254],
#          [254]], dtype=uint8),
#   array([[227],
#          [223],
#          [228],
#          ...,
#          [108],
#          [171],
#          [230]], dtype=uint8),
#   array([[ 99],
#          [103],
#          [154],
#          ...,
#          [  7],
#          [ 16],
#          [189]], dtype=uint8),
#   array([[175],
#          [ 80],
#          [255],
#          ...,
#          [ 43],
#          [198],
#          [207]], dtype=uint8),
#   array([[ 27],
#          [ 48],
#          [ 70],
#          ...,
#          [232],
#          [ 32],
#          [ 50]], dtype=uint8),
#   array([[248],
#          [252],
#          [253],
#          ...,
#          [250],
#          [ 10],
#          [  0]], dtype=uint8),
#   array([[179],
#          [135],
#          [ 88],
#          ...,
#          [255],
#          [  0],
#          [  0]], dtype=uint8),
#   array([[ 13],
#          [  0],
#          [  0],
#          ...,
#          [161],
#          [154],
#          [  0]], dtype=uint8),
#   array([[ 49],
#          [ 31],
#          [ 24],
#          ...,
#          [253],
#          [  6],
#          [  0]], dtype=uint8),
#   array([[232],
#          [224],
#          [225],
#          ...,
#          [183],
#          [190],
#          [187]], dtype=uint8),
#   array([[ 32],
#          [ 35],
#          [ 43],
#          ...,
#          [ 18],
#          [ 27],
#          [184]], dtype=uint8),
#   array([[143],
#          [125],
#          [108],
#          ...,
#          [  7],
#          [  6],
#          [  7]], dtype=uint8),
#   array([[ 20],
#          [  2],
#          [  1],
#          ...,
#          [ 47],
#          [ 26],
#          [229]], dtype=uint8),
#   array([[149],
#          [136],
#          [120],
#          ...,
#          [ 31],
#          [219],
#          [226]], dtype=uint8),
#   array([[246],
#          [203],
#          [188],
#          ...,
#          [  5],
#          [249],
#          [250]], dtype=uint8),
#   array([[192],
#          [150],
#          [ 93],
#          ...,
#          [  9],
#          [  3],
#          [250]], dtype=uint8),
#   array([[238],
#          [243],
#          [251],
#          ...,
#          [ 51],
#          [ 21],
#          [ 40]], dtype=uint8),
#   array([[ 63],
#          [ 55],
#          [246],
#          ...,
#          [ 33],
#          [  0],
#          [  0]], dtype=uint8),
#   array([[ 11],
#          [ 16],
#          [ 25],
#          ...,
#          [254],
#          [253],
#          [255]], dtype=uint8),
#   array([[217],
#          [209],
#          [195],
#          ...,
#          [ 45],
#          [  0],
#          [  0]], dtype=uint8),
#   array([[ 14],
#          [ 12],
#          [ 12],
#          ...,
#          [ 55],
#          [124],
#          [ 11]], dtype=uint8),
#   array([[ 18],
#          [ 15],
#          [ 11],
#          ...,
#          [239],
#          [242],
#          [  0]], dtype=uint8),
#   array([[0],
#          [2],
#          [2],
#          ...,
#          [0],
#          [0],
#          [0]], dtype=uint8),
#   array([[167],
#          [152],
#          [246],
#          ...,
#          [198],
#          [132],
#          [251]], dtype=uint8),
#   array([[102],
#          [117],
#          [139],
#          ...,
#          [243],
#          [207],
#          [  6]], dtype=uint8),
#   array([[  1],
#          [  0],
#          [  0],
#          ...,
#          [224],
#          [222],
#          [188]], dtype=uint8),
#   array([[ 99],
#          [147],
#          [187],
#          ...,
#          [235],
#          [228],
#          [  9]], dtype=uint8),
#   array([[127],
#          [126],
#          [206],
#          ...,
#          [ 20],
#          [ 18],
#          [ 13]], dtype=uint8),
#   array([[228],
#          [242],
#          [245],
#          ...,
#          [237],
#          [238],
#          [238]], dtype=uint8),
#   array([[231],
#          [231],
#          [249],
#          ...,
#          [ 36],
#          [220],
#          [242]], dtype=uint8),
#   array([[233],
#          [232],
#          [234],
#          ...,
#          [  5],
#          [ 40],
#          [  0]], dtype=uint8),
#   array([[124],
#          [165],
#          [192],
#          ...,
#          [  0],
#          [  0],
#          [  0]], dtype=uint8),
#   array([[218],
#          [233],
#          [236],
#          ...,
#          [238],
#          [ 55],
#          [ 10]], dtype=uint8),
#   array([[ 80],
#          [ 98],
#          [139],
#          ...,
#          [ 78],
#          [145],
#          [ 24]], dtype=uint8),
#   array([[ 21],
#          [ 21],
#          [ 21],
#          ...,
#          [  1],
#          [253],
#          [252]], dtype=uint8),
#   array([[111],
#          [ 75],
#          [ 67],
#          ...,
#          [ 22],
#          [253],
#          [ 26]], dtype=uint8),
#   array([[ 86],
#          [131],
#          [101],
#          ...,
#          [  5],
#          [ 63],
#          [  0]], dtype=uint8),
#   array([[132],
#          [ 97],
#          [ 63],
#          ...,
#          [207],
#          [ 39],
#          [249]], dtype=uint8),
#   array([[ 97],
#          [101],
#          [156],
#          ...,
#          [252],
#          [  6],
#          [  9]], dtype=uint8),
#   array([[142],
#          [183],
#          [192],
#          ...,
#          [  5],
#          [255],
#          [  0]], dtype=uint8),
#   array([[234],
#          [235],
#          [235],
#          ...,
#          [ 76],
#          [179],
#          [ 78]], dtype=uint8),
#   array([[219],
#          [235],
#          [241],
#          ...,
#          [226],
#          [181],
#          [ 18]], dtype=uint8),
#   array([[ 79],
#          [ 21],
#          [ 62],
#          ...,
#          [254],
#          [253],
#          [215]], dtype=uint8),
#   array([[224],
#          [239],
#          [242],
#          ...,
#          [232],
#          [ 99],
#          [ 22]], dtype=uint8),
#   array([[ 14],
#          [ 12],
#          [ 12],
#          ...,
#          [244],
#          [245],
#          [ 25]], dtype=uint8),
#   array([[ 35],
#          [ 35],
#          [ 34],
#          ...,
#          [253],
#          [  0],
#          [253]], dtype=uint8),
#   array([[129],
#          [140],
#          [152],
#          ...,
#          [249],
#          [245],
#          [196]], dtype=uint8),
#   array([[181],
#          [196],
#          [215],
#          ...,
#          [ 27],
#          [  4],
#          [ 19]], dtype=uint8),
#   array([[226],
#          [234],
#          [242],
#          ...,
#          [252],
#          [253],
#          [  2]], dtype=uint8),
#   array([[ 16],
#          [ 14],
#          [ 14],
#          ...,
#          [231],
#          [  0],
#          [  0]], dtype=uint8),
#   array([[202],
#          [205],
#          [209],
#          ...,
#          [189],
#          [249],
#          [247]], dtype=uint8),
#   array([[ 84],
#          [ 70],
#          [ 64],
#          ...,
#          [223],
#          [219],
#          [199]], dtype=uint8),
#   array([[ 15],
#          [ 19],
#          [ 25],
#          ...,
#          [253],
#          [  3],
#          [246]], dtype=uint8),
#   array([[ 42],
#          [ 45],
#          [ 45],
#          ...,
#          [  7],
#          [240],
#          [234]], dtype=uint8),
#   array([[  1],
#          [ 15],
#          [ 34],
#          ...,
#          [ 34],
#          [ 28],
#          [219]], dtype=uint8),
#   array([[238],
#          [236],
#          [235],
#          ...,
#          [ 21],
#          [ 73],
#          [100]], dtype=uint8),
#   array([[ 77],
#          [ 80],
#          [ 88],
#          ...,
#          [248],
#          [ 79],
#          [  0]], dtype=uint8),
#   array([[ 31],
#          [104],
#          [168],
#          ...,
#          [248],
#          [ 14],
#          [  8]], dtype=uint8),
#   array([[ 30],
#          [ 32],
#          [ 34],
#          ...,
#          [129],
#          [160],
#          [  2]], dtype=uint8),
#   array([[ 43],
#          [ 46],
#          [ 61],
#          ...,
#          [233],
#          [231],
#          [232]], dtype=uint8),
#   array([[ 21],
#          [ 22],
#          [ 32],
#          ...,
#          [  5],
#          [252],
#          [  0]], dtype=uint8),
#   array([[254],
#          [254],
#          [254],
#          ...,
#          [228],
#          [238],
#          [246]], dtype=uint8),
#   array([[11],
#          [19],
#          [18],
#          ...,
#          [ 1],
#          [ 0],
#          [ 0]], dtype=uint8),
#   array([[ 32],
#          [ 33],
#          [ 52],
#          ...,
#          [245],
#          [244],
#          [  4]], dtype=uint8),
#   array([[14],
#          [21],
#          [24],
#          ...,
#          [ 0],
#          [ 0],
#          [ 0]], dtype=uint8),
#   array([[ 26],
#          [ 31],
#          [ 46],
#          ...,
#          [232],
#          [248],
#          [155]], dtype=uint8),
#   array([[ 21],
#          [ 21],
#          [ 17],
#          ...,
#          [ 65],
#          [232],
#          [  0]], dtype=uint8),
#   array([[ 47],
#          [ 44],
#          [ 46],
#          ...,
#          [249],
#          [ 37],
#          [206]], dtype=uint8),
#   array([[ 17],
#          [ 54],
#          [ 65],
#          ...,
#          [ 78],
#          [121],
#          [213]], dtype=uint8),
#   array([[ 51],
#          [102],
#          [165],
#          ...,
#          [ 43],
#          [ 60],
#          [187]], dtype=uint8),
#   array([[ 31],
#          [ 32],
#          [ 49],
#          ...,
#          [224],
#          [239],
#          [221]], dtype=uint8),
#   array([[  0],
#          [  0],
#          [  0],
#          ...,
#          [205],
#          [203],
#          [252]], dtype=uint8),
#   array([[104],
#          [107],
#          [111],
#          ...,
#          [128],
#          [231],
#          [192]], dtype=uint8),
#   array([[  2],
#          [  5],
#          [  7],
#          ...,
#          [  8],
#          [224],
#          [ 49]], dtype=uint8),
#   array([[ 23],
#          [ 22],
#          [ 28],
#          ...,
#          [ 21],
#          [251],
#          [ 49]], dtype=uint8),
#   array([[ 34],
#          [ 33],
#          [ 44],
#          ...,
#          [ 73],
#          [ 59],
#          [212]], dtype=uint8),
#   array([[ 25],
#          [ 29],
#          [ 30],
#          ...,
#          [176],
#          [241],
#          [253]], dtype=uint8),
#   array([[ 89],
#          [ 85],
#          [ 81],
#          ...,
#          [201],
#          [ 31],
#          [ 32]], dtype=uint8),
#   array([[ 28],
#          [ 33],
#          [ 41],
#          ...,
#          [253],
#          [214],
#          [ 85]], dtype=uint8),
#   array([[226],
#          [227],
#          [231],
#          ...,
#          [252],
#          [252],
#          [  0]], dtype=uint8),
#   array([[ 29],
#          [ 25],
#          [ 36],
#          ...,
#          [255],
#          [  0],
#          [  0]], dtype=uint8),
#   array([[ 40],
#          [ 43],
#          [ 48],
#          ...,
#          [250],
#          [  4],
#          [253]], dtype=uint8),
#   array([[ 45],
#          [ 54],
#          [ 58],
#          ...,
#          [207],
#          [173],
#          [146]], dtype=uint8),
#   array([[ 13],
#          [ 12],
#          [ 16],
#          ...,
#          [233],
#          [ 19],
#          [218]], dtype=uint8),
#   array([[19],
#          [24],
#          [25],
#          ...,
#          [14],
#          [14],
#          [16]], dtype=uint8),
#   array([[ 50],
#          [ 57],
#          [ 66],
#          ...,
#          [250],
#          [ 22],
#          [  3]], dtype=uint8),
#   array([[115],
#          [ 82],
#          [110],
#          ...,
#          [ 29],
#          [153],
#          [234]], dtype=uint8),
#   array([[ 87],
#          [ 93],
#          [236],
#          ...,
#          [ 53],
#          [230],
#          [222]], dtype=uint8),
#   array([[139],
#          [177],
#          [  1],
#          ...,
#          [ 25],
#          [164],
#          [  0]], dtype=uint8),
#   array([[ 13],
#          [ 20],
#          [ 34],
#          ...,
#          [  4],
#          [239],
#          [253]], dtype=uint8),
#   array([[ 31],
#          [ 31],
#          [ 31],
#          ...,
#          [208],
#          [ 83],
#          [  0]], dtype=uint8),
#   array([[ 22],
#          [ 42],
#          [ 67],
#          ...,
#          [120],
#          [ 11],
#          [ 12]], dtype=uint8),
#   array([[76],
#          [70],
#          [73],
#          ...,
#          [34],
#          [12],
#          [ 0]], dtype=uint8),
#   array([[136],
#          [151],
#          [153],
#          ...,
#          [ 15],
#          [190],
#          [ 11]], dtype=uint8),
#   array([[109],
#          [124],
#          [157],
#          ...,
#          [246],
#          [ 42],
#          [ 77]], dtype=uint8),
#   array([[  4],
#          [  8],
#          [  9],
#          ...,
#          [239],
#          [236],
#          [250]], dtype=uint8),
#   array([[ 11],
#          [ 16],
#          [ 24],
#          ...,
#          [ 15],
#          [206],
#          [205]], dtype=uint8),
#   array([[ 65],
#          [ 53],
#          [ 25],
#          ...,
#          [ 84],
#          [111],
#          [219]], dtype=uint8),
#   array([[ 30],
#          [ 26],
#          [ 32],
#          ...,
#          [218],
#          [ 81],
#          [ 64]], dtype=uint8),
#   array([[143],
#          [169],
#          [234],
#          ...,
#          [210],
#          [212],
#          [214]], dtype=uint8),
#   array([[ 58],
#          [ 74],
#          [ 94],
#          ...,
#          [190],
#          [ 10],
#          [ 12]], dtype=uint8),
#   array([[ 35],
#          [ 41],
#          [ 48],
#          ...,
#          [ 14],
#          [225],
#          [ 23]], dtype=uint8),
#   array([[180],
#          [140],
#          [112],
#          ...,
#          [ 31],
#          [ 36],
#          [246]], dtype=uint8),
#   array([[  6],
#          [  8],
#          [  9],
#          ...,
#          [255],
#          [255],
#          [199]], dtype=uint8),
#   array([[ 62],
#          [ 60],
#          [ 49],
#          ...,
#          [209],
#          [225],
#          [167]], dtype=uint8),
#   array([[33],
#          [28],
#          [26],
#          ...,
#          [45],
#          [22],
#          [ 2]], dtype=uint8),
#   array([[ 24],
#          [ 33],
#          [ 47],
#          ...,
#          [140],
#          [ 75],
#          [249]], dtype=uint8),
#   array([[ 10],
#          [ 11],
#          [ 14],
#          ...,
#          [246],
#          [249],
#          [ 31]], dtype=uint8),
#   array([[ 61],
#          [ 70],
#          [ 96],
#          ...,
#          [252],
#          [  1],
#          [  1]], dtype=uint8),
#   array([[104],
#          [115],
#          [143],
#          ...,
#          [247],
#          [248],
#          [248]], dtype=uint8),
#   array([[181],
#          [201],
#          [218],
#          ...,
#          [248],
#          [232],
#          [  1]], dtype=uint8),
#   array([[  0],
#          [  0],
#          [  0],
#          ...,
#          [ 15],
#          [  4],
#          [236]], dtype=uint8),
#   array([[0],
#          [0],
#          [0],
#          ...,
#          [7],
#          [0],
#          [0]], dtype=uint8),
#   array([[ 54],
#          [ 68],
#          [ 87],
#          ...,
#          [ 84],
#          [250],
#          [248]], dtype=uint8),
#   array([[ 95],
#          [119],
#          [171],
#          ...,
#          [108],
#          [100],
#          [117]], dtype=uint8),
#   array([[ 24],
#          [ 26],
#          [ 34],
#          ...,
#          [212],
#          [231],
#          [ 70]], dtype=uint8),
#   array([[14],
#          [13],
#          [15],
#          ...,
#          [10],
#          [19],
#          [20]], dtype=uint8),
#   array([[32],
#          [35],
#          [39],
#          ...,
#          [89],
#          [95],
#          [95]], dtype=uint8),
#   array([[16],
#          [38],
#          [64],
#          ...,
#          [54],
#          [10],
#          [10]], dtype=uint8),
#   array([[  9],
#          [ 13],
#          [ 16],
#          ...,
#          [157],
#          [ 80],
#          [206]], dtype=uint8)])

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape # convert to float, so that interactwith sklearn ezier (). Integer type still work but sklearn gives lots  of warning
# Out:
# (133, 4096)

# %%
X
# Out:
# array([[ 47.,  53.,  72., ..., 253., 199., 251.],
#        [251., 249., 248., ..., 123., 123., 182.],
#        [ 24.,  18.,  34., ..., 244., 243., 241.],
#        ...,
#        [ 32.,  35.,  39., ...,  89.,  95.,  95.],
#        [ 16.,  38.,  64., ...,  54.,  10.,  10.],
#        [  9.,  13.,  16., ..., 157.,  80., 206.]])

# %%
X[0]
# Out:
# array([ 47.,  53.,  72., ..., 253., 199., 251.])

# %% [markdown]
# ### Model Training

# %% [markdown]
# We will use SVM with rbf kernel, tuned with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
#create pipeline 1st because we want to scale our pipeline
pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))]) #randomly chosen parameter (empirical)
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.6764705882352942

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.38      0.46         8
#            1       1.00      0.86      0.92         7
#            2       0.58      0.78      0.67         9
#            3       0.64      0.70      0.67        10
#
#     accuracy                           0.68        34
#    macro avg       0.70      0.68      0.68        34
# weighted avg       0.69      0.68      0.67        34

# %% [markdown]
# ### Use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV
